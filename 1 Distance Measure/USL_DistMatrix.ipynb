# %%
from sklearn.metrics import DistanceMetric
dist=DistanceMetric.get_metric('euclidean') #euclidean form to calculate distance
X=[[1,2],[3,4],[5,6]]
Y=[[7,8],[9,10]]
dist.pairwise(X,Y)
# Out:
# array([[ 8.48528137, 11.3137085 ],
#        [ 5.65685425,  8.48528137],
#        [ 2.82842712,  5.65685425]])

# %%
from sklearn.metrics import DistanceMetric
dist=DistanceMetric.get_metric('manhattan') #manhattan form to calculate distance
X=[[1,2],[3,4],[5,6]]
Y=[[7,8],[9,10]]
dist.pairwise(X,Y)
# Out:
# array([[12., 16.],
#        [ 8., 12.],
#        [ 4.,  8.]])

# %%
from sklearn.metrics import DistanceMetric
dist=DistanceMetric.get_metric('chebyshev') #chebyshev form to calculate distance
X=[[1,2],[3,4],[5,6]]
Y=[[7,8],[9,10]]
dist.pairwise(X,Y)
# Out:
# array([[6., 8.],
#        [4., 6.],
#        [2., 4.]])

# %%
from sklearn.metrics import DistanceMetric
dist=DistanceMetric.get_metric('minkowski') #minkowski form to calculate
X=[[1,2],[3,4],[5,6]]
Y=[[7,8],[9,10]]
dist.pairwise(X,Y)
# Out:
# array([[ 8.48528137, 11.3137085 ],
#        [ 5.65685425,  8.48528137],
#        [ 2.82842712,  5.65685425]])

# %%
from skimage.io import imread
import numpy as np
i1=imread("/content/OAS1_0028_MR1_mpr-1_100.jpg",as_gray=True)
i2=imread("/content/OAS1_0028_MR1_mpr-1_101.jpg",as_gray=True)

v1= i1.flatten()
v2= i2.flatten()

dist1=DistanceMetric.get_metric('euclidean')
dist1.pairwise([v1],[v2])
# Out:
# array([[18.74790446]])

# %%
dist2=DistanceMetric.get_metric('manhattan')
dist2.pairwise([v1],[v2])
# Out:
# array([[3567.79607843]])

# %%
dist3=DistanceMetric.get_metric('chebyshev')
dist3.pairwise([v1],[v2])
# Out:
# array([[0.73333333]])

# %%
i3=imread("/content/OAS1_0028_MR1_mpr-1_129.jpg",as_gray=True)
v3=i3.flatten()
dist1.pairwise([v1],[v3])
# Out:
# array([[73.43145925]])

# %%
dist2.pairwise([v1],[v3])
# Out:
# array([[16057.22745099]])

# %%
dist3.pairwise([v1],[v3])
# Out:
# array([[0.99215686]])
